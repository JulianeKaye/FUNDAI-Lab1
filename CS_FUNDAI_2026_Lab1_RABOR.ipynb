# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianeKaye/FUNDAI-Lab1/blob/main/CS_FUNDAI_2026_Lab1_RABOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Environment Onboarding
#
# ## Fundamentals of Artificial Intelligence
#
# **Name:** Juliane Kaye F. Rabor
# **Course:** Computer Science specialized with Artificial Intelligence
# **Section:** BSCSAI-2
# **Date:** 8/18/26
#
# **GitHub URL:** https://github.com/JulianeKaye/FUNDAI-Lab1
#
# ## Description
# This laboratory introduces the use of Google Colab and GitHub for AI laboratory activities. It also implements a simple intelligent agent.

# %%
import sys
import datetime

print("Python version:")
print(sys.version)

print("Current date:")
print(datetime.date.today())
# Out:
# Python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Current date:
# 2026-08-18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

folder_path = "content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI-Lab"
os.makedirs(folder_path, exist_ok=True)

print("Folder ready:", folder_path)
# Out:
# Folder ready: content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI-Lab

# %% [markdown]
# ## Simple Intelligent Agent
#
# This simple agent receives a room condition as a percept and produces an action.
#
# The agent follows a condition-action rule:
#
# - If the room is dirty, the agent cleans.
# - If the room is clean, the agent rests.
# - If the room condition is unknown, the agent inspects.

# %%
def simple_reflex_agent(room_condition):
  """
  A simple reflex agent that decides an action based on the room condition.
  """
  room_condition = room_condition.strip().lower()

  if room_condition == "dirty":
      return "CLEAN"
  elif room_condition == "clean":
      return "REST"
  else:
      return "INSPECT"

# %%
percepts = ["dirty", "clean", "dirty", "unknown"]

print("Simple Reflex Agent Test")
print("-" * 30)

for i, percept in enumerate(percepts, start=1):
  action = simple_reflex_agent(percept)
  print(f"Percept {i}: {percept:<8} -> Action: {action}")
# Out:
# Simple Reflex Agent Test
# ------------------------------
# Percept 1: dirty    -> Action: CLEAN
# Percept 2: clean    -> Action: REST
# Percept 3: dirty    -> Action: CLEAN
# Percept 4: unknown  -> Action: INSPECT

# %% [markdown]
# ## Perfomance Measure
#
# A simple performance measure gives a score when the agent chooses the correct acction for the given percept.

# %%
score = 0
total = len(percepts)

for percept in percepts:
  action = simple_reflex_agent(percept)

  if percept == "dirty" and action == "CLEAN":
    score += 1
  elif percept == "clean" and action == "REST":
    score += 1
  elif percept == "unknown" and action == "INSPECT":
    score += 1

print(f"Agent score: {score}/{total}")
# Out:
# Agent score: 4/4

# %% [markdown]
# ## Guide Questions and Answers
#
# ### 1. What is an intelligent agent?
# **Answer:** An intelligent agent is an entity that perceives its environment through sensors, makes decisions based on its percepts and internal logic, and acts on the environment through actuators.
#
# ### 2. What are the sensors and actuators in this simple agent example?
# **Answer:** In this example, the sensor input is the room condition percept. The actuator output is the action such as CLEAN, REST, or INSPECT.
#
# ### 3. Why is documentation important in AI laboratory work?
# **Answer:** Documentation explains the purpose of the code, shows the results, and helps the instructor evaluate the student's understanding.

# %% [markdown]
# ## Reflection
#
# ### Challenges Encountered
# - The challenges I had encountered within this activity is comprehending the use of Google Colab and Github, without any prior knowledge both platforms, and figuring out how these platforms work and their purposes.
#
# ### What I Learned
# - I have learned that Google Colab allows you to write and execute Python code without any local setup, which is a good tool for beginners. Github is a cloud-based platform used by developers where multiple people can work on the same project simultaneously without overwriting each other's files.
